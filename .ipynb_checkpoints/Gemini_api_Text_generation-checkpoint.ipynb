# %%
import os
from dotenv import load_dotenv

load_dotenv()  # take environment variables from .env.
api_key = os.getenv("GOOGLE_API_KEY")

# %%
# basic request and response 
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(

        # external role/rules.
        system_instruction="you are a car expert and car mechanic too",

        # controls internal reasoning depth
        thinking_config=types.ThinkingConfig(thinking_budget=24576)),
    contents="explain the car mechanisum"
)
print(response.text)
# Out:
# Alright, let's dive under the hood and understand the incredible symphony of engineering that makes a car work! As both a car expert and a mechanic, I'll break down the major systems. Think of a car as a complex, interconnected organism, where each part has a vital role.
#
# At its core, a car's mechanism is about **converting stored energy (fuel or electricity) into kinetic energy (motion)**, and then giving the driver the ability to **control** that motion (steer, accelerate, brake) while ensuring **safety and comfort**.
#
# Here are the main systems:
#
# ---
#
# ### 1. The Powerplant (Engine/Motor) - The Heart
#
# This is where it all begins.
#
# *   **Internal Combustion Engine (ICE):** (Most common) This is what burns fuel (gasoline or diesel) to create power.
#     *   **How it works (Simplified 4-stroke cycle):**
#         1.  **Intake:** A piston moves down, drawing a mixture of air and fuel into the cylinder.
#         2.  **Compression:** The piston moves up, compressing the air-fuel mixture.
#         3.  **Combustion (Power):** A spark plug ignites the compressed mixture (or it auto-ignites in diesel), creating an explosion that pushes the piston down with great force.
#         4.  **Exhaust:** The piston moves up again, pushing the spent gasses out of the cylinder through the exhaust system.
#     *   **Crankshaft & Connecting Rods:** The linear motion of the pistons is converted into rotational motion by connecting rods attached to a crankshaft, which is essentially a heavy-duty spinning shaft.
#     *   **Flywheel:** A heavy disk attached to the crankshaft that smooths out the engine's power pulses and provides a surface for the clutch (or torque converter) to connect to.
#     *   **Supporting Systems:**
#         *   **Fuel System:** Delivers fuel from the tank to the engine (fuel pump, injectors).
#         *   **Air Intake System:** Brings clean air to the engine (air filter, throttle body).
#         *   **Ignition System:** Creates the spark (spark plugs, coils).
#         *   **Exhaust System:** Routes spent gasses away, reduces noise, and cleans emissions (exhaust manifold, catalytic converter, muffler).
#         *   **Cooling System:** Prevents overheating (radiator, water pump, coolant).
#         *   **Lubrication System:** Reduces friction and cools engine parts (oil pump, oil filter, engine oil).
#
# *   **Electric Motor:** In electric vehicles (EVs), an electric motor converts electrical energy from a battery pack into mechanical energy to turn the wheels. It's much simpler mechanically, with fewer moving parts.
#
# ---
#
# ### 2. The Drivetrain - The Power Delivery System
#
# This system takes the engine's power and delivers it to the wheels that move the car.
#
# *   **Clutch (Manual Transmission) / Torque Converter (Automatic Transmission):**
#     *   **Clutch:** In manual cars, this allows you to disconnect the engine from the transmission momentarily to change gears without stalling the engine.
#     *   **Torque Converter:** In automatic cars, it uses fluid to smoothly transmit power from the engine to the transmission, allowing the engine to spin even when the car is stopped in gear.
# *   **Transmission (Gearbox):** This is a series of gears that allows the driver (or the car's computer) to select different gear ratios.
#     *   **Purpose:** To multiply torque (for starting and climbing hills) or multiply speed (for highway cruising) while keeping the engine in its optimal RPM range.
#     *   **Types:** Manual (driver shifts), Automatic (car shifts), Continuously Variable Transmission (CVT - no fixed gears).
# *   **Driveshaft (RWD/4WD) or Half-shafts/Axleshafts (FWD):** These rotating shafts transmit power from the transmission to the differential.
# *   **Differential:** A clever set of gears that allows the drive wheels to rotate at different speeds when turning (the outside wheel needs to spin faster than the inside wheel to cover more ground). Without it, the wheels would bind up, especially in corners.
# *   **Axles/CV Joints:** The final connection from the differential to the actual wheels. Constant Velocity (CV) joints allow power to be transmitted smoothly even when the wheels are turning or moving up and down with the suspension.
#
# **Drivetrain Layouts:**
# *   **Front-Wheel Drive (FWD):** Engine and drive wheels are at the front. Common for efficiency and packaging.
# *   **Rear-Wheel Drive (RWD):** Engine at the front (usually), power sent to rear wheels. Good for balance and performance.
# *   **All-Wheel Drive (AWD) / Four-Wheel Drive (4WD):** Power sent to all four wheels for enhanced traction.
#
# ---
#
# ### 3. The Steering System - The Direction Commander
#
# This is how you tell the car where to go.
#
# *   **Steering Wheel:** The driver's input device.
# *   **Steering Column:** Connects the steering wheel to the steering gear.
# *   **Steering Gear:** Most modern cars use a **rack-and-pinion** system. The steering wheel rotates a pinion gear, which slides a horizontal rack, moving the tie rods. Older cars or heavy-duty vehicles might use a **recirculating ball** system.
# *   **Tie Rods:** Connect the steering gear to the steering knuckles.
# *   **Steering Knuckles:** Pivot points where the wheels are attached, allowing them to turn.
# *   **Power Steering:**
#     *   **Hydraulic:** Uses a hydraulic pump (driven by the engine) to assist the driver in turning the wheels, reducing effort.
#     *   **Electric (EPAS):** Uses an electric motor to provide assistance, improving fuel efficiency and allowing for advanced features like lane-keeping assist.
#
# ---
#
# ### 4. The Braking System - The Stop Switch
#
# Crucial for safety, this system slows down or stops the vehicle.
#
# *   **Principle:** Converts the kinetic energy of the moving car into heat energy through friction.
# *   **Brake Pedal:** Driver input.
# *   **Brake Booster:** Uses engine vacuum (or an electric pump) to multiply the force applied to the brake pedal, making it easier to press.
# *   **Master Cylinder:** Converts pedal force into hydraulic pressure. It pushes brake fluid through lines.
# *   **Brake Lines & Hoses:** Steel lines (main runs) and flexible rubber hoses (near wheels for suspension movement) carry pressurized brake fluid.
# *   **Calipers (Disc Brakes):** On disc brakes, the caliper squeezes brake pads against a rotating disc (rotor) attached to the wheel. This friction slows the wheel.
# *   **Wheel Cylinders (Drum Brakes):** On drum brakes (less common on front, sometimes on rear), the wheel cylinder forces brake shoes against the inside of a spinning drum.
# *   **Parking Brake (E-brake/Handbrake):** A separate mechanical system (cable-operated) that holds the rear wheels, preventing the car from rolling when parked.
# *   **Anti-lock Braking System (ABS):** A computer-controlled safety feature that rapidly pulses the brakes on individual wheels if they start to lock up during hard braking. This prevents skidding and allows the driver to maintain steering control.
#
# ---
#
# ### 5. The Suspension System - The Ride & Handling Provider
#
# This system connects the wheels to the body of the car, managing ride comfort and handling.
#
# *   **Purpose:**
#     1.  Absorb bumps and irregularities from the road, providing a smooth ride.
#     2.  Maintain constant contact between the tires and the road for grip and control.
#     3.  Support the vehicle's weight.
# *   **Springs (Coil, Leaf, Torsion Bars):** Bear the weight of the car and absorb bumps by compressing and expanding.
# *   **Shock Absorbers (Dampers):** Crucial components that *dampen* the oscillations of the springs. Without them, the car would bounce uncontrollably. They convert kinetic energy (of the spring's movement) into heat.
# *   **Control Arms/Links:** Connect the steering knuckle to the car's frame, allowing the wheels to move up and down while maintaining proper alignment.
# *   **Ball Joints & Bushings:** Flexible joints and mounts that allow for movement while reducing friction and noise.
# *   **Sway Bars (Anti-roll Bars):** Connect the left and right suspension components. They resist body roll during cornering, keeping the car flatter.
#
# ---
#
# ### 6. The Electrical System - The Nervous System
#
# This powers everything from starting the engine to running the infotainment.
#
# *   **Battery (12V):** Stores electrical energy to start the engine and power accessories when the engine is off.
# *   **Alternator:** When the engine is running, it generates electricity to power the car's electrical systems and recharge the battery.
# *   **Starter Motor:** A powerful electric motor that turns the engine's crankshaft to get it started.
# *   **Wiring Harnesses:** Bundles of wires that transmit power and data throughout the vehicle.
# *   **Fuses & Relays:** Protect circuits from overcurrents (fuses) and switch high-current components (relays).
# *   **Engine Control Unit (ECU/ECM):** The "brain" of the car. It's a computer that monitors hundreds of sensors (engine speed, temperature, oxygen levels, etc.) and controls various engine functions (fuel injection, ignition timing) for optimal performance and emissions.
# *   **Sensors & Actuators:** Sensors gather information (e.g., speed, temperature, pressure), and actuators perform actions (e.g., open/close valves, move motors) based on ECU commands.
# *   **Lighting System:** Headlights, taillights, interior lights, etc.
#
# ---
#
# ### 7. The Chassis/Frame - The Skeleton
#
# This is the underlying structure that provides strength and support for all the other components.
#
# *   **Body-on-Frame:** (Older cars, many trucks, SUVs) A separate, rigid frame onto which the body, engine, and drivetrain are mounted. Offers high strength for towing and off-roading.
# *   **Unibody/Monocoque:** (Most modern cars) The body and frame are integrated into a single, cohesive structure. This design is lighter, more rigid, and offers better crash protection and handling for passenger vehicles.
#
# ---
#
# **In summary:** Imagine a car as a team. The **engine** generates the power, the **drivetrain** manages and delivers that power to the wheels. The **steering** and **brakes** are your control systems, allowing you to direct and stop the vehicle. The **suspension** keeps everything smooth and stable, the **electrical system** powers all the brains and lights, and the **chassis** holds it all together.
#
# Each system is meticulously designed to work in harmony, making the complex act of driving feel almost effortless. And that, in a nutshell, is the magic of car mechanisms!

# %%
# streaming responses
from google import genai

client = genai.Client()


response = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents=["Explain how AI works"]
)

# whole responses are deliverying in chunk by chunk 
for chunk in response:
    print(chunk.text, end="")
# Out:
# AI, or Artificial Intelligence, fundamentally works by **identifying patterns in data, learning from those patterns, and then using that acquired knowledge to make predictions, decisions, or perform tasks.**
#
# Think of it like teaching a very diligent student:
#
# 1.  **You give the student lots of examples (Data).**
# 2.  **You give them instructions on how to learn from those examples (Algorithms).**
# 3.  **The student studies, practices, and forms their own understanding (Learning/Training a Model).**
# 4.  **Then, when given a new problem, the student applies what they've learned to solve it (Prediction/Decision-Making).**
#
# Let's break down the core components and processes:
#
# ---
#
# ### Core Components of AI
#
# 1.  **Data: The Fuel**
#     *   AI systems are ravenous for data. This can be text, images, audio, video, sensor readings, numerical values, etc.
#     *   **Why it's crucial:** AI learns by finding correlations, anomalies, and structures within this data. The quality and quantity of data directly impact the AI's performance. "Garbage in, garbage out" is a common saying.
#     *   **Example:** To teach an AI to identify cats, you show it millions of pictures labeled "cat" and "not cat."
#
# 2.  **Algorithms: The Recipes**
#     *   These are the mathematical formulas and computational procedures that an AI system uses to process data, identify patterns, and learn.
#     *   **Why it's crucial:** Different tasks require different algorithms. An algorithm for image recognition will differ from one for generating text.
#     *   **Examples:** Linear Regression, Decision Trees, Support Vector Machines, Neural Networks (especially for Deep Learning).
#
# 3.  **Computational Power: The Engine**
#     *   Processing massive datasets and executing complex algorithms requires significant computing power.
#     *   **Why it's crucial:** Modern AI, especially deep learning, relies heavily on specialized hardware like Graphics Processing Units (GPUs) and Tensor Processing Units (TPUs) to perform parallel computations quickly.
#
# ---
#
# ### How AI "Learns" – The Training Process
#
# The "learning" in AI often falls into one of three main categories:
#
# 1.  **Supervised Learning (Most Common)**
#     *   **Concept:** The AI is given **labeled data**, meaning each piece of input data has a corresponding correct output or "answer."
#     *   **Process:** The algorithm tries to find a mapping function from the input to the output. It makes predictions, compares them to the correct answers, and adjusts its internal parameters to minimize errors. This process is repeated thousands or millions of times.
#     *   **Analogy:** Learning with flashcards where you always know the correct answer.
#     *   **Examples:**
#         *   **Image Classification:** Showing an AI millions of photos labeled "dog" or "cat" so it learns to distinguish them.
#         *   **Spam Detection:** Training an AI on emails labeled "spam" or "not spam."
#         *   **Predictive Analytics:** Predicting house prices based on historical data (size, location, features, actual price).
#
# 2.  **Unsupervised Learning**
#     *   **Concept:** The AI is given **unlabeled data** and is tasked with finding hidden patterns, structures, or relationships within it without any explicit guidance.
#     *   **Process:** The algorithms identify similarities, group data points together (clustering), or reduce the complexity of the data (dimensionality reduction).
#     *   **Analogy:** Finding groups of similar items in a vast collection without knowing what the groups should be.
#     *   **Examples:**
#         *   **Customer Segmentation:** Grouping customers based on their purchasing behavior without predefined categories.
#         *   **Anomaly Detection:** Identifying unusual patterns (e.g., fraudulent transactions).
#         *   **Topic Modeling:** Discovering themes in a collection of documents.
#
# 3.  **Reinforcement Learning**
#     *   **Concept:** The AI (called an "agent") learns by interacting with an environment, performing actions, and receiving rewards or penalties based on those actions. Its goal is to maximize the cumulative reward.
#     *   **Process:** The agent explores, takes actions, observes the consequences, and learns a "policy" (a strategy for choosing actions) that leads to the best outcomes. It's often trial and error.
#     *   **Analogy:** Teaching a dog tricks with treats (rewards) and "no" (penalties).
#     *   **Examples:**
#         *   **Game Playing:** AlphaGo learning to play Go by playing against itself millions of times.
#         *   **Robotics:** Teaching a robot to navigate a room or perform a complex motor skill.
#         *   **Self-Driving Cars:** Learning optimal driving policies in various scenarios.
#
# ---
#
# ### The AI Model
#
# Once an AI system has been trained using one of these learning methods, the result is an **AI model**.
# *   This model is essentially the "learned knowledge" – a set of adjusted parameters, weights, and rules that represent the patterns found in the training data.
# *   It's like the student's developed understanding, ready to be applied.
#
# ---
#
# ### How AI Makes Decisions/Predictions (Inference)
#
# 1.  **New Input:** When presented with new, unseen data, the trained AI model takes this input.
# 2.  **Application of Learned Patterns:** The model applies the patterns, rules, and relationships it learned during training to this new data.
# 3.  **Output:** It then generates a prediction, a classification, a decision, or performs a desired action.
#     *   **Example:** A trained image classification model sees a new picture, applies its learned "cat" vs. "dog" patterns, and outputs "This is a cat (98% confidence)."
#     *   **Example:** A language model takes a text prompt and generates a coherent paragraph based on the patterns of language it learned.
#
# ---
#
# ### Continuous Improvement
#
# AI systems aren't static. They can often be further refined:
# *   **Feedback Loops:** Human feedback or real-world performance data can be fed back into the system to retrain and improve the model over time.
# *   **New Data:** As more data becomes available, the model can be retrained to capture newer trends or adapt to changing conditions.
#
# ---
#
# ### Key AI Techniques
#
# *   **Machine Learning (ML):** The overarching field.
# *   **Deep Learning (DL):** A subfield of ML that uses **Artificial Neural Networks** with many layers (hence "deep"). These are particularly good at recognizing complex patterns in raw data like images, sound, and text.
# *   **Natural Language Processing (NLP):** Enables AI to understand, interpret, and generate human language.
# *   **Computer Vision (CV):** Allows AI to "see" and interpret visual information from images and videos.
#
# In essence, AI works by using advanced algorithms and massive amounts of data to simulate cognitive functions like learning, problem-solving, and decision-making, allowing machines to perform tasks that traditionally required human intelligence.

# %%
# multi-turn conversation 

from google import genai
import json

client = genai.Client()

# storing the conversation 
chat = client.chats.create(model="gemini-2.5-flash")

response = chat.send_message_stream("I have 2 dogs in my house.")
for chunk in response:
    print(chunk.text, end="")
print()
print('-----------')

response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")
print()
print('---------')

for message in chat.get_history():
    print(f'role - {message.role}', end=": ")
    print(message.parts[0].text)



# Saving the chat history in simple list of dict
saved_history = [
    {"role": c.role, "content": c.parts[0].text}  
    for c in chat.get_history()
]
# Out:
# That's lovely! Two dogs can bring so much joy (and sometimes a bit of mischief!).
#
# What are their names? I'd love to hear more about them if you'd like to share!
# -----------
# Based on your 2 dogs, and assuming each dog has all four paws:
#
# You have **8 paws** in your house! (2 dogs x 4 paws each)
# ---------
# role - user: I have 2 dogs in my house.
# role - model: That's lovely! Two dogs can bring so much joy (and sometimes a bit of mischief!).
#
# What are their names? I'd love to hear more about them if you'd like to share!
# role - user: How many paws are in my house?
# role - model: Based on your 2 dogs, and assuming each dog has all four paws:
#
# You have **8 paws** in your house! (2 dogs x 4 paws each)

# %%
# this is new  turn, i am requesting the information related to old conversation(another turn) without giveing chat history to this model
from google import genai

client = genai.Client()
chat = client.chats.create(model="gemini-2.5-flash")
response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")
# Out:
# I can't tell you without knowing what animals live in your house!
#
# Tell me:
# *   **How many pets do you have?**
# *   **What kind of animals are they?** (Dogs and cats have paws, birds have feet, fish don't have either!)

# %%
# Load later,if we store the chat history on some object and again restarting/creating new call for an api with existing chats, we can able to continue the old conversation 
from google import genai

client = genai.Client()

#print(saved_history)
converted_history = [
    types.Content(
        role=item["role"], 
        parts=[types.Part(text=item["content"])]
    )
    for item in saved_history
]
# Restart chat with old history
chat = client.chats.create(model="gemini-2.5-flash",history=converted_history)
response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")
# Out:
# Based on your 2 dogs, and assuming each of them has all four paws:
#
# There are **8 paws** in your house.
